# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/NLP_TH/ass2/Neural Transition-Based Dependency Parsing-20231225T025858Z-001/Neural Transition-Based Dependency Parsing"
# Out:
# /content/gdrive/MyDrive/NLP_TH/ass2/Neural Transition-Based Dependency Parsing-20231225T025858Z-001/Neural Transition-Based Dependency Parsing

# %%
# !python run.py
# Out:
# /content/gdrive/MyDrive/NLP_TH/ass2/Neural Transition-Based Dependency Parsing-20231225T025858Z-001/Neural Transition-Based Dependency Parsing/parser_transitions.py:202: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   return [("RA" if pp.stack[1] is "right" else "LA") if len(pp.buffer) == 0 else "S"
# ...
# INITIALIZING
# ...
# Loading data...
# took 2.07 seconds
# Building parser...
# took 1.22 seconds
# Loading pretrained embeddings...
# took 2.47 seconds
# Vectorizing data...
# took 2.04 seconds
# Preprocessing training data...
# took 52.74 seconds
# took 0.01 seconds
#
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# 100% 1848/1848 [02:23<00:00, 12.84it/s]
# Average Train Loss: 0.19011621898467534
# Evaluating on dev set
# 1445850it [00:00, 43040294.38it/s]
# - dev UAS: 83.70
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [02:11<00:00, 14.07it/s]
# Average Train Loss: 0.11616482305868621
# Evaluating on dev set
# 1445850it [00:00, 22567064.61it/s]
# - dev UAS: 86.22
# ...
